# %%
import selenium
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.gumtree.co.za/s-house-rentals-flat-rentals-offered/kraaifontein/buh+rein+estate/v1c9071l3100188q0p1'

# %%
html_url = requests.get(url)
s_c = html_url.status_code

if s_c == 200:
    print("Connection was a success!")
else:
    print("Something wen wrong code "+str(s_c)+" was returned.")
# Out:
# Connection was a success!

# %%
#Commiting HTML to String
html_url_str = html_url.text

# %%
html_url_str
# Out:
# '<!DOCTYPE html><html data-locale="en_ZA" lang="en" xmlns="http://www.w3.org/1999/html" class="SearchPageV1"><head><link rel="canonical" href="https://www.gumtree.co.za/s-house-rentals-flat-rentals-offered/kraaifontein/buh+rein+estate/v1c9071l3100188q0p1"><link rel="next" href="/s-house-rentals-flat-rentals-offered/kraaifontein/buh+rein+estate/page-2/v1c9071l3100188q0p2"><link rel="alternate" href="android-app://com.ebay.gumtree.za/gumtreeza/search?categoryid=9071&amp;locationid=3100188&amp;keyword=buh rein estate"><link rel="dns-prefetch" href="https://i.ebayimg.com/"><link rel="dns-prefetch" href="https://securet9.classistatic.com"><link rel="apple-touch-icon" sizes="16x16" type="image/png" href="https://securet9.classistatic.com/assets/images/en_ZA/icon-16x16-04a1420c65.png"><link rel="apple-touch-icon" sizes="32x32" type="image/png" href="https://securet9.classistatic.com/assets/images/en_ZA/icon-32x32-0bb06bd7c6.png"><link rel="apple-touch-icon" sizes="57x57" type="image/png" hr
# ...
